# %% [markdown]
# # Assignment 2: EDA

# %% [markdown]
# ##NETFLIX DATASET ANALYSIS

# %% [markdown]
# ### 1. Data Loading and Basic Checking
# ● Load Dataset
# * Import dataset using pandas
# * File: netflix_titles.csv
#
# ● Inspect Data
# * Display first 10 rows using head(10)
#
# ● Dataset Information
# * Shape of dataset (rows, columns)
# * Column names
# * Data types of each column
#
# ● Missing Values
# * Identify missing values using isnull().sum()
# * Report missing values for each column

# %% [markdown]
# ###2. Data Cleaning
#
# ● Handling Missing Values
# * Fill missing values in:
# * director → "Unknown"
# * cast → "Not Available"
# * country → "Unknown"
# * rating → "Not Rated"
# * Drop rows where date_added is missing
#
# ● Standardization
# * Convert text columns to lowercase:
# * type
# * rating
#
# ● Date Formatting
# * Convert date_added to datetime format

# %% [markdown]
# ###3. Univariate and Bivariate Analysis
#
# ● Most Common Rating
# * Find most frequent rating category using value_counts()
#
# ● Top 5 Countries
# * Identify top 5 countries with highest content
#
# ● Content Type vs Release Year
# * Compare Movies vs TV Shows
# * Calculate average release year for each type

# %% [markdown]
# ###4. Trend and Relationship Exploration
#
# ● Titles Added Per Year
# * Extract year from date_added
# * Count number of titles added each year
#
# ● Trend Analysis
# * Observe increase or decrease in content over years
# * Identify peak growth period
#
# ● Release Year vs Rating
# * Analyze relationship between release year and rating
# * Use visual methods (boxplot or scatterplot)

# %% [markdown]
# ###5. Visualizations
# ● Count Plot
# * Plot Movies vs TV Shows distribution
#
# ● Bar Chart
# * Top 5 countries by content count
#
# ● Line Chart
# * Number of titles added per year
#
# ● Scatter Plot
# * Release year vs duration
#
# ● Heatmap
# * Correlation between numeric features

# %% [markdown]
# ###6. Conclusion and Insights
# ● Key Findings
# * Movies dominate over TV Shows
# * Majority content from top countries (e.g., USA)
# * Rapid growth after 2015
# * Specific rating category is most common
#
# ● Actionable Insight
# * Netflix should focus on:
# * Regional content expansion
# * Diverse genres for global audience
